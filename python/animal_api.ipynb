# %%
import urllib.request
import xml.dom.minidom

#encodingKey = "Pb5sqj3b91BrDtfuSMvO4ZiUVg6Vlneta%2BhbuowJVbc60Ztpm5iwBFhpax6DZaGY29ER2MPIeZkifvi0ktXOew%3D%3D"
#decodingKey = "Pb5sqj3b91BrDtfuSMvO4ZiUVg6Vlneta+hbuowJVbc60Ztpm5iwBFhpax6DZaGY29ER2MPIeZkifvi0ktXOew=="

print("[START]")

# request url정의
url = "http://openapi.animal.go.kr/openapi/service/rest/abandonmentPublicSrvc/abandonmentPublic?ServiceKey=Pb5sqj3b91BrDtfuSMvO4ZiUVg6Vlneta%2BhbuowJVbc60Ztpm5iwBFhpax6DZaGY29ER2MPIeZkifvi0ktXOew%3D%3D"
request = urllib.request.Request(url)


# request보내기
response = urllib.request.urlopen(request)

# 결과 코드 정의
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    dom = xml.dom.minidom.parseString(response_body.decode('utf-8'))
    pretty_xml_as_string = dom.toprettyxml()
    print(pretty_xml_as_string)
else:
    print("Error Code:" + rescode)

print("[END]")
# Out:
# [START]
# <?xml version="1.0" ?>
# <response>
# 	<header>
# 		<resultCode>00</resultCode>
# 		<resultMsg>NORMAL SERVICE.</resultMsg>
# 	</header>
# 	<body>
# 		<items>
# 			<item>
# 				<age>2009(년생)</age>
# 				<careAddr>경상남도 창원시 의창구 창이대로 71 (명서동, 창원시농업기술센터) 축산과</careAddr>
# 				<careNm>창원유기동물보호소</careNm>
# 				<careTel>055-225-5481</careTel>
# 				<chargeNm>의창성산구</chargeNm>
# 				<colorCd>갈색</colorCd>
# 				<desertionNo>448567202100976</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201110980_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>의창구 사림동 장애인 복지관 부근 </happenPlace>
# 				<kindCd>[개] 믹스견</kindCd>
# 				<neuterYn>N</neuterYn>
# 				<noticeEdt>20211030</noticeEdt>
# 				<noticeNo>경남-창원1-2021-00559</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-225-5484</officetel>
# 				<orgNm>경상남도 창원시 의창성산구</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201110980.jpg</popfile>
# 				<processState>보호중</processState>
# 				<sexCd>M</sexCd>
# 				<specialMark>K-10-1-33 갈색. 파란색목줄 착용. 백내장있음. 주인분~빨리오세요~</specialMark>
# 				<weight>4.3(Kg)</weight>
# 			</item>
# 			<item>
# 				<age>2020(년생)</age>
# 				<careAddr>경상남도 창원시 의창구 창이대로 71 (명서동, 창원시농업기술센터) 축산과</careAddr>
# 				<careNm>창원유기동물보호소</careNm>
# 				<careTel>055-225-5481</careTel>
# 				<chargeNm>의창성산구</chargeNm>
# 				<colorCd>흰색</colorCd>
# 				<desertionNo>448567202100975</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201110614_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>의창구 북면 감계 푸르지오아파트 입구 부근 </happenPlace>
# 				<kindCd>[개] 시바</kindCd>
# 				<neuterYn>N</neuterYn>
# 				<noticeEdt>20211030</noticeEdt>
# 				<noticeNo>경남-창원1-2021-00558</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-225-5484</officetel>
# 				<orgNm>경상남도 창원시 의창성산구</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201110614.jpg</popfile>
# 				<processState>종료(반환)</processState>
# 				<sexCd>F</sexCd>
# 				<specialMark>K-10-1-32 흰색. 빨간색목줄착용</specialMark>
# 				<weight>9.4(Kg)</weight>
# 			</item>
# 			<item>
# 				<age>2021(년생)</age>
# 				<careAddr>경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원</careAddr>
# 				<careNm>태민동물병원</careNm>
# 				<careTel>010-2868-2108</careTel>
# 				<chargeNm>이상철</chargeNm>
# 				<colorCd>회색,검은색</colorCd>
# 				<desertionNo>448548202100353</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201410360_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>해인사</happenPlace>
# 				<kindCd>[고양이] 한국 고양이</kindCd>
# 				<neuterYn>U</neuterYn>
# 				<noticeEdt>20211101</noticeEdt>
# 				<noticeNo>경남-합천-2021-00352</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-930-3565</officetel>
# 				<orgNm>경상남도 합천군</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201410360.jpg</popfile>
# 				<processState>보호중</processState>
# 				<sexCd>F</sexCd>
# 				<specialMark>러시안블루 믹스 , 사람을 경계하나 .활동적임</specialMark>
# 				<weight>1(Kg)</weight>
# 			</item>
# 			<item>
# 				<age>2019(년생)</age>
# 				<careAddr>경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원</careAddr>
# 				<careNm>태민동물병원</careNm>
# 				<careTel>010-2868-2108</careTel>
# 				<chargeNm>이상철</chargeNm>
# 				<colorCd>회색.검은색</colorCd>
# 				<desertionNo>448548202100352</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201410654_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>해인사</happenPlace>
# 				<kindCd>[고양이] 한국 고양이</kindCd>
# 				<neuterYn>N</neuterYn>
# 				<noticeEdt>20211101</noticeEdt>
# 				<noticeNo>경남-합천-2021-00351</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-930-3565</officetel>
# 				<orgNm>경상남도 합천군</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201410654.jpg</popfile>
# 				<processState>보호중</processState>
# 				<sexCd>F</sexCd>
# 				<specialMark>사람을 경계하나 활발하고 잘먹음 </specialMark>
# 				<weight>4(Kg)</weight>
# 			</item>
# 			<item>
# 				<age>2021(년생)</age>
# 				<careAddr>경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원</careAddr>
# 				<careNm>태민동물병원</careNm>
# 				<careTel>010-2868-2108</careTel>
# 				<chargeNm>이상철</chargeNm>
# 				<colorCd>검은색갈색</colorCd>
# 				<desertionNo>448548202100351</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201410494_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>해인사</happenPlace>
# 				<kindCd>[고양이] 한국 고양이</kindCd>
# 				<neuterYn>N</neuterYn>
# 				<noticeEdt>20211101</noticeEdt>
# 				<noticeNo>경남-합천-2021-00350</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-930-3565</officetel>
# 				<orgNm>경상남도 합천군</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201410494.jpg</popfile>
# 				<processState>보호중</processState>
# 				<sexCd>F</sexCd>
# 				<specialMark>사람을 경계하나 활발하고 잘먹음 </specialMark>
# 				<weight>1(Kg)</weight>
# 			</item>
# 			<item>
# 				<age>2021(년생)</age>
# 				<careAddr>경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원</careAddr>
# 				<careNm>태민동물병원</careNm>
# 				<careTel>010-2868-2108</careTel>
# 				<chargeNm>이상철</chargeNm>
# 				<colorCd>검은색</colorCd>
# 				<desertionNo>448548202100350</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201410352_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>해인사</happenPlace>
# 				<kindCd>[고양이] 한국 고양이</kindCd>
# 				<neuterYn>N</neuterYn>
# 				<noticeEdt>20211101</noticeEdt>
# 				<noticeNo>경남-합천-2021-00349</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-930-3565</officetel>
# 				<orgNm>경상남도 합천군</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201410352.jpg</popfile>
# 				<processState>보호중</processState>
# 				<sexCd>F</sexCd>
# 				<specialMark>활발하며 </specialMark>
# 				<weight>1(Kg)</weight>
# 			</item>
# 			<item>
# 				<age>2019(년생)</age>
# 				<careAddr>경상남도 함양군 함양읍 함양남서로 996-76 (함양읍, 농업기술센터) </careAddr>
# 				<careNm>함양군위탁보호소</careNm>
# 				<careTel>055-960-8143</careTel>
# 				<colorCd>흰색</colorCd>
# 				<desertionNo>448546202100388</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201410309_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>함양읍</happenPlace>
# 				<kindCd>[개] 믹스견</kindCd>
# 				<neuterYn>N</neuterYn>
# 				<noticeEdt>20211101</noticeEdt>
# 				<noticeNo>경남-함양-2021-00173</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-960-8140</officetel>
# 				<orgNm>경상남도 함양군</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201410309.jpg</popfile>
# 				<processState>보호중</processState>
# 				<sexCd>M</sexCd>
# 				<specialMark>귀가 크고 쫑긋함</specialMark>
# 				<weight>10(Kg)</weight>
# 			</item>
# 			<item>
# 				<age>2019(년생)</age>
# 				<careAddr>경상남도 함양군 함양읍 함양남서로 996-76 (함양읍, 농업기술센터) </careAddr>
# 				<careNm>함양군위탁보호소</careNm>
# 				<careTel>055-960-8143</careTel>
# 				<colorCd>검정색털, 흰색 얼굴</colorCd>
# 				<desertionNo>448546202100387</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201410634_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>수동면</happenPlace>
# 				<kindCd>[개] 믹스견</kindCd>
# 				<neuterYn>N</neuterYn>
# 				<noticeEdt>20211101</noticeEdt>
# 				<noticeNo>경남-함양-2021-00174</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-960-8140</officetel>
# 				<orgNm>경상남도 함양군</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201410634.jpg</popfile>
# 				<processState>보호중</processState>
# 				<sexCd>F</sexCd>
# 				<specialMark>사고로 인해 하반신을 쓰지 못함</specialMark>
# 				<weight>8(Kg)</weight>
# 			</item>
# 			<item>
# 				<age>2014(년생)</age>
# 				<careAddr>경상남도 함양군 함양읍 함양남서로 996-76 (함양읍, 농업기술센터) </careAddr>
# 				<careNm>함양군위탁보호소</careNm>
# 				<careTel>055-960-8143</careTel>
# 				<colorCd>흰색</colorCd>
# 				<desertionNo>448546202100386</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201410484_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>휴천면 운서리</happenPlace>
# 				<kindCd>[개] 믹스견</kindCd>
# 				<neuterYn>N</neuterYn>
# 				<noticeEdt>20211101</noticeEdt>
# 				<noticeNo>경남-함양-2021-00175</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-960-8140</officetel>
# 				<orgNm>경상남도 함양군</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201410484.jpg</popfile>
# 				<processState>보호중</processState>
# 				<sexCd>F</sexCd>
# 				<specialMark>착하고 겁이 많음</specialMark>
# 				<weight>25(Kg)</weight>
# 			</item>
# 			<item>
# 				<age>2019(년생)</age>
# 				<careAddr>경상남도 거제시 사등면 두동로1길 109 (사등면, 한국자원재생공사폐비닐적재장) 거제시유기동물보호소</careAddr>
# 				<careNm>거제시유기동물보호소</careNm>
# 				<careTel>055-639-6368</careTel>
# 				<chargeNm>김은섭</chargeNm>
# 				<colorCd>흰색</colorCd>
# 				<desertionNo>448537202101104</desertionNo>
# 				<filename>http://www.animal.go.kr/files/shelter/2021/10/202110201710588_s.jpg</filename>
# 				<happenDt>20211020</happenDt>
# 				<happenPlace>사곡 모래실 </happenPlace>
# 				<kindCd>[개] 믹스견</kindCd>
# 				<neuterYn>N</neuterYn>
# 				<noticeEdt>20211101</noticeEdt>
# 				<noticeNo>경남-거제-2021-01108</noticeNo>
# 				<noticeSdt>20211020</noticeSdt>
# 				<officetel>055-639-6363</officetel>
# 				<orgNm>경상남도 거제시</orgNm>
# 				<popfile>http://www.animal.go.kr/files/shelter/2021/10/202110201710588.jpg</popfile>
# 				<processState>보호중</processState>
# 				<sexCd>M</sexCd>
# 				<specialMark>목줄착용</specialMark>
# 				<weight>5(Kg)</weight>
# 			</item>
# 		</items>
# 		<numOfRows>10</numOfRows>
# 		<pageNo>1</pageNo>
# 		<totalCount>10807</totalCount>
# 	</body>
# </response>
#
# [END]
